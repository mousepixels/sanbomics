# %%
from sanbomics.plots import volcano

# %%
volcano('/home/jrlab2019/youtube/deseq/DE_results.csv', save = 'derk')

# %%
volcano?

# %%
ls
# Out:
# notebooks/  sanbomics/  Untitled.ipynb

# %%
save = 'derk'

# %%
if save == True:
    print(save)
